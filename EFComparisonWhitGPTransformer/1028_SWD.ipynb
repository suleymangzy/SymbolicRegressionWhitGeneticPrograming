# %%
import openml
from gplearn.genetic import SymbolicTransformer, SymbolicRegressor
from evolutionary_forest.forest import EvolutionaryForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
dataset = openml.datasets.get_dataset(1028)

X, y, _, _ = dataset.get_data(dataset_format="dataframe", target=dataset.default_target_attribute)

# %%
X = (X - X.mean()) / X.std()

# %%
y = (y - y.mean()) / y.std()

# %%
transformer = SymbolicTransformer()
transformer.fit(X, y)
# Out:
# SymbolicTransformer()

# %%
X_transformed = transformer.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# %%
r = EvolutionaryForestRegressor()
r.fit(X_train, y_train)
print("R2 Score of test samples whit the EF model: ", r2_score(y_test, r.predict(X_test)))
# Out:
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# R2 Score of test samples whit the EF model:  0.36921845420190347

# %%
est_gp = SymbolicRegressor()
est_gp.fit(X_train, y_train)
print("R2 Score of test samples whit the SRGP model: ", r2_score(y_test, est_gp.predict(X_test)))
# Out:
# R2 Score of test samples whit the SRGP model:  0.33136394384641676
