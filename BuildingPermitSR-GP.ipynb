# %%
from gplearn.genetic import SymbolicTransformer, SymbolicRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

# %%
X_train = pd.read_csv('DataSets/X_train.csv')
y_train = pd.read_csv('DataSets/y_train.csv')
X_test = pd.read_csv('DataSets/X_test.csv')
y_test = pd.read_csv('DataSets/y_test.csv')

# %%
msno.matrix(X_train)
plt.show()

# %%
df = pd.concat([X_train, y_train], axis=1)

# %%
df_new, df_insignificant = train_test_split(
    df,
    test_size=0.9,
    random_state=42,
    shuffle=True,
    stratify=df['Permit Process Time']
)
# Out:
# Orijinal Veri Sayısı: 1022632
# Yeni Veri Sayısı: 102263
# Yeni Veri Seti Sınıf Dağılımı (Oranlar):
# Permit Process Time
# 0     0.038469
# 24    0.038469
# 11    0.038469
# 16    0.038469
# 8     0.038469
# 25    0.038460
# 3     0.038460
# 6     0.038460
# 13    0.038460
# 23    0.038460
# 18    0.038460
# 15    0.038460
# 10    0.038460
# 22    0.038460
# 1     0.038460
# 19    0.038460
# 7     0.038460
# 17    0.038460
# 14    0.038460
# 9     0.038460
# 4     0.038460
# 5     0.038460
# 21    0.038460
# 12    0.038460
# 20    0.038460
# 2     0.038460
# Name: proportion, dtype: float64

# %%
msno.matrix(df_new)
plt.show()

# %%
df_new['Permit Process Time'].value_counts()
# Out:
# Permit Process Time
# 0     3934
# 24    3934
# 11    3934
# 16    3934
# 8     3934
# 25    3933
# 3     3933
# 6     3933
# 13    3933
# 23    3933
# 18    3933
# 15    3933
# 10    3933
# 22    3933
# 1     3933
# 19    3933
# 7     3933
# 17    3933
# 14    3933
# 9     3933
# 4     3933
# 5     3933
# 21    3933
# 12    3933
# 20    3933
# 2     3933
# Name: count, dtype: int64

# %%
X_train = df_new.drop(columns=['Permit Process Time'])
y_train = df_new['Permit Process Time']
