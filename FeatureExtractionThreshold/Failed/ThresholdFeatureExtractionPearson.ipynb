# %%
from Functions.FeatureExtractionThreshold_FeatureSelectionMethodsFailed import run_comparative_analysis_threshold_pearson

# %%
sets_id = [192, 210, 228, 229, 505, 529, 542, 547, 560, 663, 666, 678, 706, 712, 1027, 1028, 1029, 1030]

threshold_result_list = run_comparative_analysis_threshold_pearson(sets_id=sets_id)
