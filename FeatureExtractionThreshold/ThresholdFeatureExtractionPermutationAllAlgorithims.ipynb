# %%
from Functions.FeatureExtractionThreshold import run_comparative_analysis_threshold_permutation_imp_all_algorithims

# %%
sets_id = [192, 542, 547, 665, 678, 706, 712, 1028, 1029, 1030]

threshold_result_list = run_comparative_analysis_threshold_permutation_imp_all_algorithims(sets_id=sets_id)
