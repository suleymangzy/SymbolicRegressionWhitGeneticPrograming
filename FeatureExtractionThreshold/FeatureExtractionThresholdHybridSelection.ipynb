# %%
from Functions.FeatureExtractionThresholdAndFeatureSelection import run_hybrid_comparative_analysis1

# %%
sets_id = [192, 210, 228, 229, 505, 529, 542, 547, 560, 663, 666, 678, 706, 712, 1027, 1028, 1029, 1030]

threshold_result_list = run_hybrid_comparative_analysis1(sets_id=sets_id , min_importance=0.05)
# Out:
# ############################################################
# Processing: Dataset ID 192
# ############################################################
# Dataset: vineyard | Raw Features: 2
#
# > Generating EF Candidates...
# > Generating STGP Candidates...
#
#    >>> JUDGE: RF <<<
#
#    [EF Selection] - RF
#    +--------+----------+------------+--------------------------------------------------------------------------------------------+
#    |  Rank  |   Type   |   Score    | Expression                                                                                 |
#    +--------+----------+------------+--------------------------------------------------------------------------------------------+
#    |   1    |    EF    |   0.3665   | $\frac{X_{0} + 1}{\sqrt{4 \cdot X_{0}^{2} + 1}}$                                           |
#    +--------+----------+------------+--------------------------------------------------------------------------------------------+
#
# ...
