# %%
from Functions.FeatureExtractionThresholdAndFeatureSelection import run_comparative_analysis_rf_selection

# %%
sets_id = [192, 542, 547, 665, 678, 706, 712, 1028, 1029, 1030]

threhold_results_list = run_comparative_analysis_rf_selection(sets_id=sets_id)
