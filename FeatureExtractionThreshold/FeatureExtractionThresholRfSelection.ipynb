# %%
from Functions.FeatureExtractionThresholdAndFeatureSelection import run_comparative_analysis_rf_selection

# %%
sets_id = [192, 210, 228, 229, 505, 529, 542, 547, 560, 663, 666, 678, 706, 712, 1027, 1028, 1029, 1030]

threshold_results_list1 = run_comparative_analysis_rf_selection(sets_id=sets_id, min_importance=0.05)
