# %%
from FE2 import run_comparative_analysis

# %%
sets_id = [192, 542, 547, 665, 678, 706, 712, 1028, 1029, 1030]

threshold_result_list = run_comparative_analysis(sets_id=sets_id)
# Out:
# Procesing: Dataset ID 192...
# Raw vineyard columns: 2
# EF vineyard columns: 7
# STGP+EF vineyard columns: 12
# Procesing: Dataset ID 542...
# Raw pollution columns: 15
# EF pollution columns: 20
# STGP+EF pollution columns: 25
# Procesing: Dataset ID 547...
# Raw no2 columns: 7
# EF no2 columns: 12
# STGP+EF no2 columns: 17
# Procesing: Dataset ID 665...
# Raw sleuth_case2002 columns: 10
# EF sleuth_case2002 columns: 15
# STGP+EF sleuth_case2002 columns: 20
# Procesing: Dataset ID 678...
# Raw visualizing_environmental columns: 3
# EF visualizing_environmental columns: 8
# STGP+EF visualizing_environmental columns: 13
# Procesing: Dataset ID 706...
# Raw sleuth_case1202 columns: 11
# EF sleuth_case1202 columns: 16
# STGP+EF sleuth_case1202 columns: 21
# Procesing: Dataset ID 712...
# Raw chscase_geyser1 columns: 2
# EF chscase_geyser1 columns: 7
# STGP+EF chscase_geyser1 columns: 12
# Procesing: Dataset ID 1028...
# Raw SWD columns: 10
# EF SWD columns: 15
# STGP+EF SWD columns: 20
# Procesing: Dataset ID 1029...
# Raw LEV columns: 4
# EF LEV columns: 9
# STGP+EF LEV columns: 14
# Procesing: Dataset ID 1030...
# Raw ERA columns: 4
# EF ERA columns: 9
# STGP+EF ERA columns: 14

# %%
result_list = run_comparative_analysis(sets_id=sets_id, use_threshold=False)
# Out:
# Procesing: Dataset ID 192...
# Raw vineyard columns: 2
# EF vineyard columns: 12
# STGP+EF vineyard columns: 22
# Procesing: Dataset ID 542...
# Raw pollution columns: 15
# EF pollution columns: 25
# STGP+EF pollution columns: 35
# Procesing: Dataset ID 547...
# Raw no2 columns: 7
# EF no2 columns: 17
# STGP+EF no2 columns: 27
# Procesing: Dataset ID 665...
# Raw sleuth_case2002 columns: 10
# EF sleuth_case2002 columns: 20
# STGP+EF sleuth_case2002 columns: 30
# Procesing: Dataset ID 678...
# Raw visualizing_environmental columns: 3
# EF visualizing_environmental columns: 13
# STGP+EF visualizing_environmental columns: 23
# Procesing: Dataset ID 706...
# Raw sleuth_case1202 columns: 11
# EF sleuth_case1202 columns: 21
# STGP+EF sleuth_case1202 columns: 31
# Procesing: Dataset ID 712...
# Raw chscase_geyser1 columns: 2
# EF chscase_geyser1 columns: 12
# STGP+EF chscase_geyser1 columns: 22
# Procesing: Dataset ID 1028...
# Raw SWD columns: 10
# EF SWD columns: 20
# STGP+EF SWD columns: 30
# Procesing: Dataset ID 1029...
# Raw LEV columns: 4
# EF LEV columns: 14
# STGP+EF LEV columns: 24
# Procesing: Dataset ID 1030...
# Raw ERA columns: 4
# EF ERA columns: 14
# STGP+EF ERA columns: 24

# %%
threshold_result_list.to_excel('threshold_result_list_5.xlsx')
result_list.to_excel('result_list_10.xlsx')
