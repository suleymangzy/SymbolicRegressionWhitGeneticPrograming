# %%
from Function_Fe_Mean import *

# %%
sets_id = [192, 542, 547, 665, 678, 706, 712, 1028, 1029, 1030]

results_df_sorted = srgp_and_ef_fe(sets_id)
# Out:
# ==================== Analiz Başlıyor ====================
# >> İşleniyor: vineyard..(192)
# >> İşleniyor: pollutio..(542)
# >> İşleniyor: no2..(547)
# >> İşleniyor: sleuth_c..(665)
# >> İşleniyor: visualiz..(678)
# >> İşleniyor: sleuth_c..(706)
# >> İşleniyor: chscase_..(712)
# >> İşleniyor: SWD..(1028)
# >> İşleniyor: LEV..(1029)
# >> İşleniyor: ERA..(1030)
#
# ############################## SONUÇ MATRİSİ (DÜZENLENMİŞ) ##############################
# Dataset   ERA..(1030)                           LEV..(1029)                           SWD..(1028)                           chscase_..(712)                           no2..(547)                           pollutio..(542)                           sleuth_c..(665)                           sleuth_c..(706)                           vineyard..(192)                           visualiz..(678)                              General
# ...

# %%
results_df_sorted.to_excel('SRGP_and_EF.xlsx')
