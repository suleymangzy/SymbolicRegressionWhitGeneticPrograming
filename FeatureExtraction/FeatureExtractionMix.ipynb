# %%
from Functions.FeatureExtractionMix import run_comprehensive_analysis

# %%
sets_id = [192, 210, 228, 229, 505, 529, 542, 547, 560, 663, 666, 678, 706, 712, 1027, 1028, 1029, 1030]

results_table = run_comprehensive_analysis(sets_id=sets_id)
# Out:
# ################################################################################
# Processing Dataset ID: 192
# ################################################################################
# Dataset: vineyard | Samples: 41 | Original Features: 2
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | mul(mul(sub(-0.865, sub(X0, X0)), -0.493), sub(X0, mul(mul(X1, 0.302), add(add(mul(mul(... |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   2    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   3    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   4    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   5    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   6    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   7    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   8    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   9    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   10   |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $X_{0}$                                                                                    |
#    |   2    |       EF        | $X_{0}^{3}$                                                                                |
#    |   3    |       EF        | $- X_{0}$                                                                                  |
#    |   4    |       EF        | $X_{0} + 1$                                                                                |
#    |   5    |       EF        | $X_{0}^{2}$                                                                                |
#    |   6    |       EF        | $\frac{\sqrt{2} \cdot X_{0}}{2}$                                                           |
#    |   7    |       EF        | $- X_{0} + \frac{X_{0}}{\sqrt{\frac{X_{0}^{2}}{X_{0}^{2} + 1} + 1}}$                       |
#    |   8    |       EF        | $2 \cdot X_{0}^{2}$                                                                        |
#    |   9    |       EF        | $- X_{0}^{2}$                                                                              |
#    |   10   |       EF        | $2 \cdot X_{0} + 1$                                                                        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   2    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   3    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   4    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   5    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   6    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   7    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   8    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   9    |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   10   |      STGP       | sub(div(0.884, mul(X0, X1)), div(sub(X1, 0.884), div(0.034, X0)))                          |
#    |   11   |       EF        | $X_{0}$                                                                                    |
#    |   12   |       EF        | $X_{0}^{3}$                                                                                |
#    |   13   |       EF        | $- X_{0}$                                                                                  |
#    |   14   |       EF        | $X_{0} + 1$                                                                                |
#    |   15   |       EF        | $X_{0}^{2}$                                                                                |
#    |   16   |       EF        | $\frac{\sqrt{2} \cdot X_{0}}{2}$                                                           |
#    |   17   |       EF        | $- X_{0} + \frac{X_{0}}{\sqrt{\frac{X_{0}^{2}}{X_{0}^{2} + 1} + 1}}$                       |
#    |   18   |       EF        | $2 \cdot X_{0}^{2}$                                                                        |
#    |   19   |       EF        | $- X_{0}^{2}$                                                                              |
#    |   20   |       EF        | $2 \cdot X_{0} + 1$                                                                        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 210
# ################################################################################
# Could not download file from https://openml.org/datasets/0000/0210/dataset_210.pq: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: https://www.openml.org/datasets/0000/0210/dataset_210.pq (Caused by ResponseError('too many redirects'))
# Failed to download parquet, fallback on ARFF.
# Dataset: cloud | Samples: 86 | Original Features: 9
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | mul(mul(0.658, add(X1, X0)), 0.722)                                                        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   2    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   3    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   4    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   5    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   6    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   7    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   8    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   9    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   10   |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $X_{0} + X_{1}$                                                                            |
#    |   2    |       EF        | $X_{0} + \frac{X_{1}}{\sqrt{X_{8}^{2} + 1}}$                                               |
#    |   3    |       EF        | $- X_{0} + \frac{X_{0}}{\sqrt{X_{1}^{2} + 1}}$                                             |
#    |   4    |       EF        | $\frac{X_{1}}{\sqrt{X_{8}^{2} + 1}}$                                                       |
#    |   5    |       EF        | $2 \cdot X_{1}$                                                                            |
#    |   6    |       EF        | $X_{0} + \frac{X_{1}}{\sqrt{X_{1}^{2} + 1}}$                                               |
#    |   7    |       EF        | $\frac{X_{1}^{2}}{\sqrt{X_{1}^{2} + 1}}$                                                   |
#    |   8    |       EF        | $- X_{1} - 1$                                                                              |
#    |   9    |       EF        | $\frac{X_{0} \cdot X_{1}}{\sqrt{X_{1}^{2} + 1}}$                                           |
#    |   10   |       EF        | $X_{0}$                                                                                    |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   2    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   3    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   4    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   5    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   6    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   7    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   8    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   9    |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   10   |      STGP       | sub(mul(0.289, X2), add(X1, X0))                                                           |
#    |   11   |       EF        | $X_{0} + X_{1}$                                                                            |
#    |   12   |       EF        | $X_{0} + \frac{X_{1}}{\sqrt{X_{8}^{2} + 1}}$                                               |
#    |   13   |       EF        | $- X_{0} + \frac{X_{0}}{\sqrt{X_{1}^{2} + 1}}$                                             |
#    |   14   |       EF        | $\frac{X_{1}}{\sqrt{X_{8}^{2} + 1}}$                                                       |
#    |   15   |       EF        | $2 \cdot X_{1}$                                                                            |
#    |   16   |       EF        | $X_{0} + \frac{X_{1}}{\sqrt{X_{1}^{2} + 1}}$                                               |
#    |   17   |       EF        | $\frac{X_{1}^{2}}{\sqrt{X_{1}^{2} + 1}}$                                                   |
#    |   18   |       EF        | $- X_{1} - 1$                                                                              |
#    |   19   |       EF        | $\frac{X_{0} \cdot X_{1}}{\sqrt{X_{1}^{2} + 1}}$                                           |
#    |   20   |       EF        | $X_{0}$                                                                                    |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 228
# ################################################################################
# Could not download file from https://openml.org/datasets/0000/0228/dataset_228.pq: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: https://www.openml.org/datasets/0000/0228/dataset_228.pq (Caused by ResponseError('too many redirects'))
# Failed to download parquet, fallback on ARFF.
# Dataset: elusage | Samples: 44 | Original Features: 13
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | sub(div(mul(mul(-0.127, X11), X10), X2), X0)                                               |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(add(sub(sub(sub(div(X0, X11), X0), X0), X0), X1), X0)                                  |
#    |   2    |      STGP       | sub(sub(add(sub(div(X0, X11), X0), X1), X0), X0)                                           |
#    |   3    |      STGP       | sub(add(sub(div(X0, X11), X0), sub(add(sub(div(X0, X11), X0), X1), X0)), X0)               |
#    |   4    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   5    |      STGP       | add(sub(sub(div(X0, X11), X0), X0), X1)                                                    |
#    |   6    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   7    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   8    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   9    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   10   |      STGP       | sub(X0, add(sub(div(X0, X11), X0), X1))                                                    |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $- X_{0} + X_{8}$                                                                          |
#    |   2    |       EF        | $X_{0} + X_{11}$                                                                           |
#    |   3    |       EF        | $\frac{X_{0} + X_{12}}{\sqrt{X_{5}^{2} \cdot \left(X_{2} + X_{7}\right)^{2} + 1}}$         |
#    |   4    |       EF        | $\frac{X_{0}}{\sqrt{X_{6}^{2} + 1}} - \frac{X_{5}}{\sqrt{X_{12}^{2} + 1}}$                 |
#    |   5    |       EF        | $\frac{X_{0}}{\sqrt{4 \cdot X_{11}^{2} + 1}}$                                              |
#    |   6    |       EF        | $\frac{X_{0}}{\sqrt{X_{6}^{2} + 1}} - \frac{X_{5}}{\sqrt{X_{7}^{2} + 1}}$                  |
#    |   7    |       EF        | $X_{0} \cdot X_{6}$                                                                        |
#    |   8    |       EF        | $\frac{X_{0} + X_{12}}{\sqrt{X_{10}^{2} \cdot \left(X_{2} + X_{7}\right)^{2} + 1}}$        |
#    |   9    |       EF        | $X_{1} \cdot X_{8} + X_{10} \cdot X_{12}^{2}$                                              |
#    |   10   |       EF        | $X_{0} + X_{10}$                                                                           |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(add(sub(sub(sub(div(X0, X11), X0), X0), X0), X1), X0)                                  |
#    |   2    |      STGP       | sub(sub(add(sub(div(X0, X11), X0), X1), X0), X0)                                           |
#    |   3    |      STGP       | sub(add(sub(div(X0, X11), X0), sub(add(sub(div(X0, X11), X0), X1), X0)), X0)               |
#    |   4    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   5    |      STGP       | add(sub(sub(div(X0, X11), X0), X0), X1)                                                    |
#    |   6    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   7    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   8    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   9    |      STGP       | sub(add(sub(div(X0, X11), X0), X1), X0)                                                    |
#    |   10   |      STGP       | sub(X0, add(sub(div(X0, X11), X0), X1))                                                    |
#    |   11   |       EF        | $- X_{0} + X_{8}$                                                                          |
#    |   12   |       EF        | $X_{0} + X_{11}$                                                                           |
#    |   13   |       EF        | $\frac{X_{0} + X_{12}}{\sqrt{X_{5}^{2} \cdot \left(X_{2} + X_{7}\right)^{2} + 1}}$         |
#    |   14   |       EF        | $\frac{X_{0}}{\sqrt{X_{6}^{2} + 1}} - \frac{X_{5}}{\sqrt{X_{12}^{2} + 1}}$                 |
#    |   15   |       EF        | $\frac{X_{0}}{\sqrt{4 \cdot X_{11}^{2} + 1}}$                                              |
#    |   16   |       EF        | $\frac{X_{0}}{\sqrt{X_{6}^{2} + 1}} - \frac{X_{5}}{\sqrt{X_{7}^{2} + 1}}$                  |
#    |   17   |       EF        | $X_{0} \cdot X_{6}$                                                                        |
#    |   18   |       EF        | $\frac{X_{0} + X_{12}}{\sqrt{X_{10}^{2} \cdot \left(X_{2} + X_{7}\right)^{2} + 1}}$        |
#    |   19   |       EF        | $X_{1} \cdot X_{8} + X_{10} \cdot X_{12}^{2}$                                              |
#    |   20   |       EF        | $X_{0} + X_{10}$                                                                           |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 229
# ################################################################################
# Could not download file from https://openml.org/datasets/0000/0229/dataset_229.pq: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: https://www.openml.org/datasets/0000/0229/dataset_229.pq (Caused by ResponseError('too many redirects'))
# Failed to download parquet, fallback on ARFF.
# Dataset: pwLinear | Samples: 160 | Original Features: 10
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | sub(mul(sub(add(div(0.324, X0), add(X5, X4)), X0), 0.324), div(0.324, X0))                 |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(sub(sub(add(X6, X4), X0), sub(X0, sub... |
#    |   2    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   3    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   4    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   5    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   6    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   7    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   8    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   9    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   10   |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $- X_{0} + X_{4}$                                                                          |
#    |   2    |       EF        | $1 - X_{0}$                                                                                |
#    |   3    |       EF        | $- X_{0} + 2 \cdot X_{4}$                                                                  |
#    |   4    |       EF        | $- X_{0} \cdot X_{1} + X_{0} + X_{2}$                                                      |
#    |   5    |       EF        | $- X_{0} \cdot X_{1} + X_{2} + X_{4}$                                                      |
#    |   6    |       EF        | $- X_{0} \cdot X_{1} + X_{1} + X_{2}$                                                      |
#    |   7    |       EF        | $X_{5} + X_{6}$                                                                            |
#    |   8    |       EF        | $X_{0} - X_{6}$                                                                            |
#    |   9    |       EF        | $X_{4} + X_{5}$                                                                            |
#    |   10   |       EF        | $X_{0} - X_{4} + 1$                                                                        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(sub(sub(add(X6, X4), X0), sub(X0, sub... |
#    |   2    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   3    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   4    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   5    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   6    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   7    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   8    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   9    |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   10   |      STGP       | sub(sub(add(X6, X4), X0), sub(X0, sub(add(X2, add(X4, X1)), sub(X0, X5))))                 |
#    |   11   |       EF        | $- X_{0} + X_{4}$                                                                          |
#    |   12   |       EF        | $1 - X_{0}$                                                                                |
#    |   13   |       EF        | $- X_{0} + 2 \cdot X_{4}$                                                                  |
#    |   14   |       EF        | $- X_{0} \cdot X_{1} + X_{0} + X_{2}$                                                      |
#    |   15   |       EF        | $- X_{0} \cdot X_{1} + X_{2} + X_{4}$                                                      |
#    |   16   |       EF        | $- X_{0} \cdot X_{1} + X_{1} + X_{2}$                                                      |
#    |   17   |       EF        | $X_{5} + X_{6}$                                                                            |
#    |   18   |       EF        | $X_{0} - X_{6}$                                                                            |
#    |   19   |       EF        | $X_{4} + X_{5}$                                                                            |
#    |   20   |       EF        | $X_{0} - X_{4} + 1$                                                                        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 505
# ################################################################################
# Could not download file from https://openml.org/datasets/0000/0505/dataset_505.pq: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: https://www.openml.org/datasets/0000/0505/dataset_505.pq (Caused by ResponseError('too many redirects'))
# Failed to download parquet, fallback on ARFF.
# Dataset: tecator | Samples: 192 | Original Features: 124
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | sub(sub(X21, X123), X53)                                                                   |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | X122                                                                                       |
#    |   2    |      STGP       | X122                                                                                       |
#    |   3    |      STGP       | X122                                                                                       |
#    |   4    |      STGP       | X122                                                                                       |
#    |   5    |      STGP       | X122                                                                                       |
#    |   6    |      STGP       | X122                                                                                       |
#    |   7    |      STGP       | X122                                                                                       |
#    |   8    |      STGP       | X122                                                                                       |
#    |   9    |      STGP       | X122                                                                                       |
#    |   10   |      STGP       | X122                                                                                       |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $X_{122} - \frac{1}{\sqrt{\left(X_{42} - X_{52}\right)^{2} + 1}}$                          |
#    |   2    |       EF        | $X_{122} + X_{123}$                                                                        |
#    |   3    |       EF        | $X_{122} - \frac{\sqrt{2}}{2}$                                                             |
#    |   4    |       EF        | $X_{122} - \frac{1}{\sqrt{\left(- \frac{X_{37}}{\sqrt{1 + \frac{1}{X_{60}^{2} + 1}}} + ... |
#    |   5    |       EF        | $2 \cdot X_{122}$                                                                          |
#    |   6    |       EF        | $\frac{X_{122}}{\sqrt{\frac{X_{122}^{2}}{X_{53}^{2} + 1} + 1}}$                            |
#    |   7    |       EF        | $\frac{X_{122}}{\sqrt{1 + \frac{1}{X_{60}^{2} + 1}} \cdot \sqrt{X_{57}^{2} + 1} \cdot \... |
#    |   8    |       EF        | $X_{122} - \frac{1}{\sqrt{\left(- \frac{X_{37}}{\sqrt{\frac{X_{106}^{2}}{X_{60}^{2} + 1... |
#    |   9    |       EF        | $X_{122} - \frac{1}{\sqrt{X_{122}^{2} + 1}}$                                               |
#    |   10   |       EF        | $X_{122}$                                                                                  |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | X122                                                                                       |
#    |   2    |      STGP       | X122                                                                                       |
#    |   3    |      STGP       | X122                                                                                       |
#    |   4    |      STGP       | X122                                                                                       |
#    |   5    |      STGP       | X122                                                                                       |
#    |   6    |      STGP       | X122                                                                                       |
#    |   7    |      STGP       | X122                                                                                       |
#    |   8    |      STGP       | X122                                                                                       |
#    |   9    |      STGP       | X122                                                                                       |
#    |   10   |      STGP       | X122                                                                                       |
#    |   11   |       EF        | $X_{122} - \frac{1}{\sqrt{\left(X_{42} - X_{52}\right)^{2} + 1}}$                          |
#    |   12   |       EF        | $X_{122} + X_{123}$                                                                        |
#    |   13   |       EF        | $X_{122} - \frac{\sqrt{2}}{2}$                                                             |
#    |   14   |       EF        | $X_{122} - \frac{1}{\sqrt{\left(- \frac{X_{37}}{\sqrt{1 + \frac{1}{X_{60}^{2} + 1}}} + ... |
#    |   15   |       EF        | $2 \cdot X_{122}$                                                                          |
#    |   16   |       EF        | $\frac{X_{122}}{\sqrt{\frac{X_{122}^{2}}{X_{53}^{2} + 1} + 1}}$                            |
#    |   17   |       EF        | $\frac{X_{122}}{\sqrt{1 + \frac{1}{X_{60}^{2} + 1}} \cdot \sqrt{X_{57}^{2} + 1} \cdot \... |
#    |   18   |       EF        | $X_{122} - \frac{1}{\sqrt{\left(- \frac{X_{37}}{\sqrt{\frac{X_{106}^{2}}{X_{60}^{2} + 1... |
#    |   19   |       EF        | $X_{122} - \frac{1}{\sqrt{X_{122}^{2} + 1}}$                                               |
#    |   20   |       EF        | $X_{122}$                                                                                  |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 529
# ################################################################################
# Could not download file from https://openml.org/datasets/0000/0529/dataset_529.pq: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: https://www.openml.org/datasets/0000/0529/dataset_529.pq (Caused by ResponseError('too many redirects'))
# Failed to download parquet, fallback on ARFF.
# Dataset: pollen | Samples: 3078 | Original Features: 4
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | sub(sub(mul(0.367, sub(X1, X0)), X3), X0)                                                  |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | add(add(X0, X3), add(add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, add(mul(X1, -0.40... |
#    |   2    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   3    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   4    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   5    |      STGP       | add(X3, add(add(mul(X1, -0.409), mul(0.524, X0)), X0))                                     |
#    |   6    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   7    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   8    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   9    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   10   |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $\frac{X_{0}}{\sqrt{X_{0}^{2} + 1}}$                                                       |
#    |   2    |       EF        | $X_{0} + X_{3} + 1$                                                                        |
#    |   3    |       EF        | $\frac{X_{0}}{\sqrt{X_{1}^{2} + 1}} - X_{1} + 3 \cdot X_{3}$                               |
#    |   4    |       EF        | $- X_{0} + X_{1}$                                                                          |
#    |   5    |       EF        | $\frac{\sqrt{2} \cdot X_{0}}{2}$                                                           |
#    |   6    |       EF        | $\frac{X_{1} + X_{3}}{\sqrt{\left(X_{0} + X_{2}\right)^{2} + 1}}$                          |
#    |   7    |       EF        | $X_{0} + X_{2}$                                                                            |
#    |   8    |       EF        | $2 \cdot X_{0}$                                                                            |
#    |   9    |       EF        | $\frac{X_{0}}{\sqrt{X_{3}^{2} + 1}}$                                                       |
#    |   10   |       EF        | $X_{0} - 1$                                                                                |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | add(add(X0, X3), add(add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, add(mul(X1, -0.40... |
#    |   2    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   3    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   4    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   5    |      STGP       | add(X3, add(add(mul(X1, -0.409), mul(0.524, X0)), X0))                                     |
#    |   6    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   7    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   8    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   9    |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   10   |      STGP       | add(add(X0, X3), add(mul(X1, -0.409), mul(0.524, X0)))                                     |
#    |   11   |       EF        | $\frac{X_{0}}{\sqrt{X_{0}^{2} + 1}}$                                                       |
#    |   12   |       EF        | $X_{0} + X_{3} + 1$                                                                        |
#    |   13   |       EF        | $\frac{X_{0}}{\sqrt{X_{1}^{2} + 1}} - X_{1} + 3 \cdot X_{3}$                               |
#    |   14   |       EF        | $- X_{0} + X_{1}$                                                                          |
#    |   15   |       EF        | $\frac{\sqrt{2} \cdot X_{0}}{2}$                                                           |
#    |   16   |       EF        | $\frac{X_{1} + X_{3}}{\sqrt{\left(X_{0} + X_{2}\right)^{2} + 1}}$                          |
#    |   17   |       EF        | $X_{0} + X_{2}$                                                                            |
#    |   18   |       EF        | $2 \cdot X_{0}$                                                                            |
#    |   19   |       EF        | $\frac{X_{0}}{\sqrt{X_{3}^{2} + 1}}$                                                       |
#    |   20   |       EF        | $X_{0} - 1$                                                                                |
# ...
#    |   19   |       EF        | $X_{0} + X_{2}$                                                                            |
#    |   20   |       EF        | $\frac{\sqrt{2} \cdot X_{6}}{2} - 1$                                                       |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 1029
# ################################################################################
# Dataset: LEV | Samples: 800 | Original Features: 4
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | mul(0.749, add(mul(X0, 0.631), X1))                                                        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | add(add(add(X2, add(X0, X1)), add(add(add(X1, X0), add(X2, add(X1, X0))), add(X3, X1)))... |
#    |   2    |      STGP       | add(add(add(X2, add(X1, X0)), add(X1, X0)), add(X3, X1))                                   |
#    |   3    |      STGP       | add(add(add(X0, X1), add(X2, add(X0, X1))), add(X3, X1))                                   |
#    |   4    |      STGP       | add(add(X1, X0), add(add(X3, X1), add(X2, add(X0, X1))))                                   |
#    |   5    |      STGP       | add(add(X0, X1), add(add(X2, add(X0, X1)), add(X3, X1)))                                   |
#    |   6    |      STGP       | add(add(X3, X1), add(add(X1, X0), add(X2, add(X1, X0))))                                   |
#    |   7    |      STGP       | add(add(add(X1, X0), X2), add(add(X0, X1), add(X3, X1)))                                   |
#    |   8    |      STGP       | add(add(X1, X0), add(add(X2, add(X0, X1)), add(X3, X1)))                                   |
#    |   9    |      STGP       | add(add(X2, add(X1, X0)), add(add(X0, X1), add(X3, X1)))                                   |
#    |   10   |      STGP       | add(add(X3, X1), add(add(add(X1, X0), X2), add(X0, X1)))                                   |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $X_{0} \cdot X_{1}$                                                                        |
#    |   2    |       EF        | $X_{0} \cdot X_{2}$                                                                        |
#    |   3    |       EF        | $X_{0}^{2}$                                                                                |
#    |   4    |       EF        | $X_{1} \cdot X_{2}$                                                                        |
#    |   5    |       EF        | $X_{0} \cdot \left(X_{0} + X_{1} \cdot X_{3}\right)$                                       |
#    |   6    |       EF        | $X_{0} + X_{1}$                                                                            |
#    |   7    |       EF        | $X_{2} + X_{3}$                                                                            |
#    |   8    |       EF        | $X_{1}^{2} + X_{2}$                                                                        |
#    |   9    |       EF        | $X_{0}$                                                                                    |
#    |   10   |       EF        | $2 \cdot X_{0}$                                                                            |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | add(add(add(X2, add(X0, X1)), add(add(add(X1, X0), add(X2, add(X1, X0))), add(X3, X1)))... |
#    |   2    |      STGP       | add(add(add(X2, add(X1, X0)), add(X1, X0)), add(X3, X1))                                   |
#    |   3    |      STGP       | add(add(add(X0, X1), add(X2, add(X0, X1))), add(X3, X1))                                   |
#    |   4    |      STGP       | add(add(X1, X0), add(add(X3, X1), add(X2, add(X0, X1))))                                   |
#    |   5    |      STGP       | add(add(X0, X1), add(add(X2, add(X0, X1)), add(X3, X1)))                                   |
#    |   6    |      STGP       | add(add(X3, X1), add(add(X1, X0), add(X2, add(X1, X0))))                                   |
#    |   7    |      STGP       | add(add(add(X1, X0), X2), add(add(X0, X1), add(X3, X1)))                                   |
#    |   8    |      STGP       | add(add(X1, X0), add(add(X2, add(X0, X1)), add(X3, X1)))                                   |
#    |   9    |      STGP       | add(add(X2, add(X1, X0)), add(add(X0, X1), add(X3, X1)))                                   |
#    |   10   |      STGP       | add(add(X3, X1), add(add(add(X1, X0), X2), add(X0, X1)))                                   |
#    |   11   |       EF        | $X_{0} \cdot X_{1}$                                                                        |
#    |   12   |       EF        | $X_{0} \cdot X_{2}$                                                                        |
#    |   13   |       EF        | $X_{0}^{2}$                                                                                |
#    |   14   |       EF        | $X_{1} \cdot X_{2}$                                                                        |
#    |   15   |       EF        | $X_{0} \cdot \left(X_{0} + X_{1} \cdot X_{3}\right)$                                       |
#    |   16   |       EF        | $X_{0} + X_{1}$                                                                            |
#    |   17   |       EF        | $X_{2} + X_{3}$                                                                            |
#    |   18   |       EF        | $X_{1}^{2} + X_{2}$                                                                        |
#    |   19   |       EF        | $X_{0}$                                                                                    |
#    |   20   |       EF        | $2 \cdot X_{0}$                                                                            |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
#
# ################################################################################
# Processing Dataset ID: 1030
# ################################################################################
# Dataset: ERA | Samples: 800 | Original Features: 4
#
# > Applying: Symbolic Regressor (SRGP)...
#
#    Generated Features: 1. GP (Symb. Reg)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      SRGP       | mul(add(X0, X1), 0.430)                                                                    |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Symbolic Transformer (STGP)...
#
#    Generated Features: 2. Transformer
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   2    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   3    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   4    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   5    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   6    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   7    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   8    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   9    |      STGP       | add(add(X3, add(X2, add(add(X1, X0), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   10   |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Evolutionary Forest (EF)...
#
#    Generated Features: 3. EF (Evo. Forest)
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |       EF        | $X_{0} - X_{1}$                                                                            |
#    |   2    |       EF        | $X_{0} + 1$                                                                                |
#    |   3    |       EF        | $X_{1} \cdot \left(X_{1} + 1\right)$                                                       |
#    |   4    |       EF        | $- X_{1}$                                                                                  |
#    |   5    |       EF        | $X_{1} + 1$                                                                                |
#    |   6    |       EF        | $X_{0}$                                                                                    |
#    |   7    |       EF        | $X_{0} \cdot X_{1}$                                                                        |
#    |   8    |       EF        | $X_{1} - 1$                                                                                |
#    |   9    |       EF        | $X_{2}$                                                                                    |
#    |   10   |       EF        | $1 - X_{1}$                                                                                |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# > Applying: Hybrid (Transformer + EF)...
#
#    Generated Features: 4. Transformer+EF
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    | Index  |     Source      | Expression / Name                                                                          |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#    |   1    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   2    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   3    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   4    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   5    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   6    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   7    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   8    |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   9    |      STGP       | add(add(X3, add(X2, add(add(X1, X0), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   10   |      STGP       | add(add(X3, add(X2, add(add(X0, X1), X1))), add(add(X2, add(add(X0, X1), X1)), X0))        |
#    |   11   |       EF        | $X_{0} - X_{1}$                                                                            |
#    |   12   |       EF        | $X_{0} + 1$                                                                                |
#    |   13   |       EF        | $X_{1} \cdot \left(X_{1} + 1\right)$                                                       |
#    |   14   |       EF        | $- X_{1}$                                                                                  |
#    |   15   |       EF        | $X_{1} + 1$                                                                                |
#    |   16   |       EF        | $X_{0}$                                                                                    |
#    |   17   |       EF        | $X_{0} \cdot X_{1}$                                                                        |
#    |   18   |       EF        | $X_{1} - 1$                                                                                |
#    |   19   |       EF        | $X_{2}$                                                                                    |
#    |   20   |       EF        | $1 - X_{1}$                                                                                |
#    +--------+-----------------+--------------------------------------------------------------------------------------------+
#
# >>> Evaluating Models with Augmented Datasets...
