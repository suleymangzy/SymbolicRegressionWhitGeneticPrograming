# %%
from Functions import feature_extraction_and_model_training

# %%
sets_id = [192, 542, 547, 665, 678, 706, 712, 1028, 1029, 1030]

# %%
results_df_sorted1 = feature_extraction_and_model_training(set_id=sets_id, min_importance_threshold=0.05, aos=False, orginal_features=False)
results_df_sorted1.to_excel('Feature_Extraction_Not_AOS_Not_Original_Feature.xlsx', index=False)
# Out:
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 6 out of 52 EF features.
# ✅ Selected 1 out of 52  ST features.
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 3 out of 197 EF features.
# ✅ Selected 3 out of 65  ST features.
# ...

# %%
results_df_sorted2 = feature_extraction_and_model_training(set_id=sets_id, min_importance_threshold=0.05, aos=False, orginal_features=True)
results_df_sorted2.to_excel('Feature_Extraction_Not_AOS_Original_Feature.xlsx', index=False)
# Out:
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 6 out of 52 EF features.
# ✅ Selected 1 out of 52  ST features.
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 2 out of 189 EF features.
# ✅ Selected 3 out of 65  ST features.
# ...

# %%
results_df_sorted3 = feature_extraction_and_model_training(set_id=sets_id, min_importance_threshold=0.05, aos=True, orginal_features=False)
results_df_sorted3.to_excel('Feature_Extraction_AOS_Not_Original_Feature.xlsx', index=False)
# Out:
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 4 out of 186 EF features.
# ✅ Selected 1 out of 52  ST features.
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 2 out of 368 EF features.
# ✅ Selected 3 out of 65  ST features.
# ...

# %%
results_df_sorted4 = feature_extraction_and_model_training(set_id=sets_id, min_importance_threshold=0.05, aos=True, orginal_features=True)
results_df_sorted4.to_excel('Feature_Extraction_AOS_Original_Feature.xlsx', index=False)
# Out:
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 6 out of 130 EF features.
# ✅ Selected 1 out of 52  ST features.
# C:\Users\SGUZEY\Documents\Lisans Dersleri\Bitirme Projesi\SRwhitGP\.venv\lib\site-packages\deap\gp.py:257: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "
# ✅ Selected 3 out of 297 EF features.
# ✅ Selected 3 out of 65  ST features.
# ...
